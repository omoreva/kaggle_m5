# %%
import pandas as pd
import numpy as np

# %%
data_location = '../04_submissions/lightGBM_no_fe.csv'
last_submission = pd.read_csv(data_location)

# %%
last_submission.head()
# Out:
#                               id        F1        F2        F3        F4  \
# 0  HOBBIES_1_001_CA_1_validation  0.663926  0.608443  0.567978  0.570818
# 1  HOBBIES_1_002_CA_1_validation  0.140730  0.119249  0.120528  0.131663
# 2  HOBBIES_1_003_CA_1_validation  0.336024  0.303254  0.303254  0.310913
# 3  HOBBIES_1_004_CA_1_validation  1.571163  1.390618  1.335540  1.465894
# 4  HOBBIES_1_005_CA_1_validation  0.759940  0.680799  0.695291  0.698131
#
#          F5        F6        F7        F8        F9  ...       F19       F20  \
# 0  0.665598  0.845279  0.362367  0.320595  0.288588  ...  0.314443  0.395596
# 1  0.151975  0.208956  0.349040  0.288694  0.251395  ...  0.290085  0.368644
# 2  0.376704  0.482113  0.423460  0.347161  0.313319  ...  0.376360  0.477762
# 3  1.580209  2.182620  2.386300  1.647291  1.472650  ...  1.609980  2.235519
# 4  0.816059  1.086747  1.269171  0.915828  0.817610  ...  0.950103  1.265394
#
# ...

# %%
last_submission.loc[:, last_submission.columns != 'id'] = 1.02*last_submission.loc[:, last_submission.columns != 'id']

# %%
last_submission.to_csv( '../04_submissions/lightGBM_alpha.csv', index = False)
