# %%
import pandas as pd
import numpy as np
from datetime  import datetime  
from datetime import timedelta  
import lightgbm as lgb
from sklearn import preprocessing, metrics
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt
import seaborn as sns
import mlflow
import mlflow.lightgbm
import seaborn as sns

# %%
data_location = '../00_data/sample_submission.csv'
submission = pd.read_csv(data_location)

# %%
params = {
        'boosting_type': 'gbdt',
        'metric': 'rmse',
        'objective':  'poisson',
        'n_jobs': -1,
        'seed': 0,
        'learning_rate': 0.05, 
        'bagging_fraction': 0.9,
        'bagging_freq': 10, 
        'colsample_bytree': 0.75,
        'num_iterations': 4000,
        'early_stopping_round': 200,
        'max_bin': 100,
        'boost_from_average': False}

# %%
data_location = '../04_submissions/best_submission.csv'
best_submission = pd.read_csv(data_location)
best_sumbission_mod = pd.read_csv(data_location)

# %%
evaluation_rows = [row for row in submission['id'] if 'evaluation' in row] 
evaluation = submission[submission['id'].isin(evaluation_rows)]

validation_rows = [row for row in submission['id'] if 'validation' in row] 
validation_csv = submission[submission['id'].isin(validation_rows)]

# %%
i = 'smooth'
X_val = pd.read_pickle("../01_preprocessed_data/X_{}_val.pkl".format(i))
X_val.columns

not_features = ['id', 'd', 'date', 'start_date', 'demand_type']
X_val.columns[~X_val.columns.isin(not_features) ]
# Out:
# Index(['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'weekday',
#        'month', 'event_name_1', 'event_type_1', 'year', 'event_name_2',
#        'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI', 'days_from_start',
#        'start_date_from_start', 'sell_price', 'ADI', 'CV2',
#        'avg_weekday_demand', 'avg_demand', 'max_demand', 'quantile025_week',
#        'max_weekday_demand', 'avg_price', 'cheaper_than_usual', 'lag_28',
#        'lag_29', 'lag_30', 'lag_31', 'lag_32', 'lag_33', 'lag_34', 'lag_35',
#        'lag_36', 'lag_37', 'lag_38', 'lag_39', 'lag_40', 'lag_41', 'lag_42',
#        'lag_43', 'lag_44', 'lag_45', 'lag_46', 'lag_47', 'lag_48', 'lag_49',
#        'lag_50', 'lag_51', 'lag_52', 'lag_53', 'lag_54', 'lag_55', 'lag_56',
#        'lag_57', 'rmean_28_7', 'rmean_28_14', 'rmean_28_28'],
#       dtype='object')

# %%
features = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 
            'weekday', 'month', 'year',
            'event_name_1', 'event_type_1', 'year', 'event_name_2', 'event_type_2',
            'snap_CA', 'snap_TX', 'snap_WI',
            'days_from_start', 'start_date_from_start', 'sell_price', 'avg_price', 
            'ADI', 'CV2',
           'avg_weekday_demand', 'avg_demand', 'max_demand', 'quantile025_week', 'max_weekday_demand',  
            'lag_28', 'lag_29', 'lag_30', 'lag_31', 'lag_32',
       'lag_33', 'lag_34', 'lag_35', 'lag_36', 'lag_37', 'lag_38', 'lag_39',
       'lag_40', 'lag_41', 'lag_42', 'rmean_28_7', 'rmean_28_28']
validation = pd.DataFrame(columns=submission.columns)

for i in ['smooth', 'erratic', 'lumpy', 'intermittent']:
    print(i)
    X_val = pd.read_pickle("../01_preprocessed_data/X_{}_val.pkl".format(i))
    y_val = pd.read_pickle("../01_preprocessed_data/y_{}_val.pkl".format(i))
    X_test = pd.read_pickle("../01_preprocessed_data/X_{}_test.pkl".format(i))
    X_train = pd.read_pickle("../01_preprocessed_data/X_{}_train.pkl".format(i))
    y_train = pd.read_pickle("../01_preprocessed_data/y_{}_train.pkl".format(i))
    print(X_train.shape)
    features = X_train.columns[~X_train.columns.isin(not_features) ]

    train_set = lgb.Dataset(X_train[features],y_train)
    val_set = lgb.Dataset(X_val[features], y_val)
    model = lgb.train(params, train_set, valid_sets = [train_set, val_set], verbose_eval = 100)
    
    val_pred = model.predict(X_val[features])
    val_score = metrics.mean_absolute_error(val_pred, y_val)
    print(f'Our val mae score is {val_score}')

    y_test = model.predict(X_test[features])
    X_test['demand'] = y_test
    predictions = X_test[['id', 'days_from_start', 'demand']]
    predictions = pd.pivot(predictions, index = 'id', columns = 'days_from_start', values = 'demand').reset_index()
    predictions.columns = ['id'] + ['F' + str(j + 1) for j in range(28)]
    validation = validation.append(submission[['id']].merge(predictions, on = 'id'))
# Out:
# smooth
# (2802233, 65)
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 5.50124	valid_1's rmse: 4.4259
# [200]	training's rmse: 5.27164	valid_1's rmse: 4.35223
# [300]	training's rmse: 5.12962	valid_1's rmse: 4.3198
# [400]	training's rmse: 5.01808	valid_1's rmse: 4.29423
# [500]	training's rmse: 4.94304	valid_1's rmse: 4.27338
# [600]	training's rmse: 4.88129	valid_1's rmse: 4.2662
# [700]	training's rmse: 4.82811	valid_1's rmse: 4.26139
# [800]	training's rmse: 4.77777	valid_1's rmse: 4.25097
# [900]	training's rmse: 4.74094	valid_1's rmse: 4.24503
# [1000]	training's rmse: 4.71451	valid_1's rmse: 4.24043
# [1100]	training's rmse: 4.68053	valid_1's rmse: 4.23321
# [1200]	training's rmse: 4.64705	valid_1's rmse: 4.23115
# [1300]	training's rmse: 4.62172	valid_1's rmse: 4.22953
# [1400]	training's rmse: 4.60474	valid_1's rmse: 4.22841
# [1500]	training's rmse: 4.58324	valid_1's rmse: 4.22628
# [1600]	training's rmse: 4.56278	valid_1's rmse: 4.22452
# [1700]	training's rmse: 4.54543	valid_1's rmse: 4.22375
# [1800]	training's rmse: 4.52815	valid_1's rmse: 4.21966
# [1900]	training's rmse: 4.50641	valid_1's rmse: 4.21823
# [2000]	training's rmse: 4.48896	valid_1's rmse: 4.21531
# [2100]	training's rmse: 4.47375	valid_1's rmse: 4.21297
# [2200]	training's rmse: 4.4622	valid_1's rmse: 4.21309
# [2300]	training's rmse: 4.44787	valid_1's rmse: 4.2139
# [2400]	training's rmse: 4.43169	valid_1's rmse: 4.2165
# Early stopping, best iteration is:
# [2250]	training's rmse: 4.45355	valid_1's rmse: 4.2118
# Our val mae score is 2.63135982625868
# erratic
# (1250301, 65)
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 7.02912	valid_1's rmse: 5.16364
# [200]	training's rmse: 6.85851	valid_1's rmse: 5.10464
# [300]	training's rmse: 6.74196	valid_1's rmse: 5.06052
# [400]	training's rmse: 6.65202	valid_1's rmse: 5.02717
# [500]	training's rmse: 6.57036	valid_1's rmse: 5.009
# [600]	training's rmse: 6.50666	valid_1's rmse: 4.99719
# [700]	training's rmse: 6.45319	valid_1's rmse: 4.98145
# [800]	training's rmse: 6.40658	valid_1's rmse: 4.96793
# [900]	training's rmse: 6.36371	valid_1's rmse: 4.96211
# [1000]	training's rmse: 6.32446	valid_1's rmse: 4.9583
# [1100]	training's rmse: 6.28913	valid_1's rmse: 4.95171
# [1200]	training's rmse: 6.25438	valid_1's rmse: 4.94767
# [1300]	training's rmse: 6.22096	valid_1's rmse: 4.93657
# [1400]	training's rmse: 6.18549	valid_1's rmse: 4.92697
# [1500]	training's rmse: 6.15433	valid_1's rmse: 4.92533
# [1600]	training's rmse: 6.12719	valid_1's rmse: 4.9189
# [1700]	training's rmse: 6.09855	valid_1's rmse: 4.91448
# [1800]	training's rmse: 6.07241	valid_1's rmse: 4.9102
# [1900]	training's rmse: 6.04832	valid_1's rmse: 4.90765
# [2000]	training's rmse: 6.0254	valid_1's rmse: 4.90411
# [2100]	training's rmse: 6.00374	valid_1's rmse: 4.90273
# [2200]	training's rmse: 5.98472	valid_1's rmse: 4.89561
# [2300]	training's rmse: 5.9654	valid_1's rmse: 4.89266
# [2400]	training's rmse: 5.94644	valid_1's rmse: 4.89285
# [2500]	training's rmse: 5.92497	valid_1's rmse: 4.89138
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 5.92497	valid_1's rmse: 4.89138
# Our val mae score is 3.1441812053133296
# lumpy
# (7845291, 65)
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 3.44363	valid_1's rmse: 3.0882
# [200]	training's rmse: 3.4015	valid_1's rmse: 3.04673
# [300]	training's rmse: 3.36775	valid_1's rmse: 3.02557
# [400]	training's rmse: 3.34123	valid_1's rmse: 3.01107
# [500]	training's rmse: 3.31877	valid_1's rmse: 2.99995
# [600]	training's rmse: 3.29886	valid_1's rmse: 2.99199
# [700]	training's rmse: 3.28035	valid_1's rmse: 2.98453
# [800]	training's rmse: 3.26598	valid_1's rmse: 2.98025
# [900]	training's rmse: 3.25137	valid_1's rmse: 2.97675
# [1000]	training's rmse: 3.23602	valid_1's rmse: 2.97959
# [1100]	training's rmse: 3.22332	valid_1's rmse: 2.98023
# Early stopping, best iteration is:
# [942]	training's rmse: 3.24527	valid_1's rmse: 2.97637
# Our val mae score is 1.5230980201823239
# intermittent
# (31172843, 48)
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# C:\Users\omore\Anaconda3\lib\site-packages\lightgbm\engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 200 rounds
# [100]	training's rmse: 1.43761	valid_1's rmse: 1.27824
# [200]	training's rmse: 1.4034	valid_1's rmse: 1.22958
# [300]	training's rmse: 1.37931	valid_1's rmse: 1.21666
# [400]	training's rmse: 1.35739	valid_1's rmse: 1.21005
# [500]	training's rmse: 1.34199	valid_1's rmse: 1.2075
# [600]	training's rmse: 1.32662	valid_1's rmse: 1.20649
# [700]	training's rmse: 1.31467	valid_1's rmse: 1.20389
# [800]	training's rmse: 1.30566	valid_1's rmse: 1.20272
# [900]	training's rmse: 1.29621	valid_1's rmse: 1.19982
# [1000]	training's rmse: 1.28889	valid_1's rmse: 1.19874
# [1100]	training's rmse: 1.282	valid_1's rmse: 1.19714
# [1200]	training's rmse: 1.27687	valid_1's rmse: 1.19557
# [1300]	training's rmse: 1.27177	valid_1's rmse: 1.19508
# [1400]	training's rmse: 1.26741	valid_1's rmse: 1.19366
# [1500]	training's rmse: 1.26359	valid_1's rmse: 1.19335
# [1600]	training's rmse: 1.26053	valid_1's rmse: 1.19261
# [1700]	training's rmse: 1.25686	valid_1's rmse: 1.19216
# [1800]	training's rmse: 1.25249	valid_1's rmse: 1.19124
# [1900]	training's rmse: 1.249	valid_1's rmse: 1.19058
# [2000]	training's rmse: 1.24623	valid_1's rmse: 1.1898
# [2100]	training's rmse: 1.2422	valid_1's rmse: 1.18921
# [2200]	training's rmse: 1.23761	valid_1's rmse: 1.18856
# [2300]	training's rmse: 1.23567	valid_1's rmse: 1.18791
# [2400]	training's rmse: 1.23305	valid_1's rmse: 1.18746
# [2500]	training's rmse: 1.23096	valid_1's rmse: 1.18687
# Did not meet early stopping. Best iteration is:
# [2500]	training's rmse: 1.23096	valid_1's rmse: 1.18687
# Our val mae score is 0.6964429627540105

# %%
j = 0
for i in ['smooth', 'erratic', 'lumpy', 'intermittent']:
    print(i)
    y_train = pd.read_pickle("../01_preprocessed_data/y_{}_train.pkl".format(i))
    plt.figure(j)
    demand_hist = sns.distplot(y_train, kde=False)
    demand_hist.set_title('Histogram of demand')
    demand_hist.set_xlabel('demand')
    j = j + 1

# %%
validation = validation.set_index('id')
validation = validation.reindex(index=validation_csv['id'])
validation = validation.reset_index()

# %%
validation
# Out:
#                                   id        F1        F2        F3        F4  \
# 0      HOBBIES_1_001_CA_1_validation  0.799065  0.869764  0.657275  0.697928
# 1      HOBBIES_1_002_CA_1_validation  0.208321  0.208850  0.238790  0.317993
# 2      HOBBIES_1_003_CA_1_validation  0.346909  0.373315  0.454035  0.427522
# 3      HOBBIES_1_004_CA_1_validation  1.558728  1.169458  1.229521  1.478049
# 4      HOBBIES_1_005_CA_1_validation  0.969478  0.932750  1.072849  1.321421
# ...                              ...       ...       ...       ...       ...
# 30485    FOODS_3_823_WI_3_validation  0.186480  0.164663  0.163177  0.151526
# 30486    FOODS_3_824_WI_3_validation  0.018881  0.015600  0.020429  0.017143
# 30487    FOODS_3_825_WI_3_validation  0.746174  0.666316  0.580303  0.577067
# 30488    FOODS_3_826_WI_3_validation  1.251314  1.384200  0.828008  0.808960
# 30489    FOODS_3_827_WI_3_validation  1.971734  2.420304  1.867670  1.532590
#
#              F5        F6        F7        F8        F9  ...       F19  \
# 0      0.795097  1.149443  0.702657  0.589669  0.811142  ...  0.792314
# 1      0.320472  0.410593  0.344531  0.229894  0.255558  ...  0.236902
# 2      0.571883  0.654753  0.443517  0.315970  0.295823  ...  0.472336
# 3      1.616623  2.819198  3.383890  1.550922  1.153043  ...  1.390460
# 4      1.361801  1.840234  1.730573  0.993375  1.086030  ...  1.073707
# ...         ...       ...       ...       ...       ...  ...       ...
# 30485  0.159930  0.138610  0.164931  0.147953  0.138075  ...  0.451449
# 30486  0.014281  0.044324  0.088973  0.092323  0.082461  ...  0.060283
# 30487  0.710203  0.814787  0.932584  0.891197  1.015141  ...  0.884629
# 30488  0.736838  0.956725  1.411428  0.960564  1.487577  ...  0.954894
# 30489  2.098407  2.633236  2.286329  2.620093  2.949034  ...  1.864425
#
#             F20       F21       F22       F23       F24       F25       F26  \
# 0      1.063433  0.820414  0.784491  0.844902  0.658491  0.677865  0.774130
# 1      0.270632  0.220344  0.193605  0.206120  0.265070  0.294165  0.261134
# 2      0.804128  0.463790  0.369378  0.422717  0.404220  0.441400  0.631753
# 3      2.380183  3.603662  1.460221  1.254960  1.158493  1.524919  1.540216
# 4      1.669524  1.554901  1.005444  0.895339  0.960614  1.031997  1.139614
# ...         ...       ...       ...       ...       ...       ...       ...
# 30485  0.393090  0.592209  0.333084  0.274143  0.273776  0.302354  0.294925
# 30486  0.066875  0.109355  0.075140  0.044245  0.052963  0.045446  0.040530
# 30487  1.044641  1.258245  0.666013  0.582008  0.667491  0.560259  0.666583
# 30488  1.171925  1.608698  0.822978  0.958253  0.689277  0.624440  0.788797
# 30489  2.025316  1.840718  1.524435  1.807451  1.218694  1.109855  1.632355
#
#             F27       F28
# 0      1.002490  0.800212
# 1      0.290830  0.249213
# 2      0.915390  0.521499
# 3      2.567826  3.428963
# 4      1.585365  1.612251
# ...         ...       ...
# 30485  0.276061  0.423915
# 30486  0.054773  0.077213
# 30487  0.752230  0.803899
# 30488  0.909626  1.399936
# 30489  1.667175  1.497959
#
# [30490 rows x 29 columns]

# %%
final = pd.concat([validation, evaluation])

# %%
final.to_csv('../04_submissions/submission-by_demand_type_poisson.csv', index = False)

# %%
with open("../04_submissions/best_submission_day1-{}.txt".format(i), "a") as outfile:
    outfile.write("\n".join(features))
    outfile.write("\n")
    outfile.write(str(params) )
    outfile.write("\n")
    #outfile.write(str(val_score))
    #outfile.write("\n")

# %%
X_val.groupby(['demand_type'])['demand_type', 'abs_difference'].agg(['mean']).reset_index()

# %%
X_val[X_val['demand_type'] == 'smooth'].sort_values(by = 'abs_difference')

# %%
data_location = '../04_submissions/best_submission.csv'
best_submission_orig = pd.read_csv(data_location)

# %%
best_submission_orig[best_submission_orig['id'].isin(X_test['id'])]

# %%
best_submission[best_submission['id'].isin(X_test['id'])]
